# %% [markdown]
# ## Setup
#
# You will need to make a copy of this notebook in your Google Drive before you can edit the homework files. You can do so with **File &rarr; Save a copy in Drive**.

# %%
#@title mount your Google Drive
#@markdown Your work will be stored in a folder called `cs285_f2023` by default to prevent Colab instance timeouts from deleting your edits.

import os
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
#@title set up mount symlink

DRIVE_PATH = '/content/gdrive/My\ Drive/cs285_f2023'
DRIVE_PYTHON_PATH = DRIVE_PATH.replace('\\', '')
if not os.path.exists(DRIVE_PYTHON_PATH):
  # %mkdir $DRIVE_PATH

## the space in `My Drive` causes some issues,
## make a symlink to avoid this
SYM_PATH = '/content/cs285_f2023'
if not os.path.exists(SYM_PATH):
  # !ln -s $DRIVE_PATH $SYM_PATH

# %%
#@title apt install requirements

#@markdown Run each section with Shift+Enter

#@markdown Double-click on section headers to show code.

# !apt update
# !apt install -y --no-install-recommends \
        build-essential \
        curl \
        git \
        gnupg2 \
        make \
        cmake \
        ffmpeg \
        swig \
        libz-dev \
        unzip \
        zlib1g-dev \
        libglfw3 \
        libglfw3-dev \
        libxrandr2 \
        libxinerama-dev \
        libxi6 \
        libxcursor-dev \
        libgl1-mesa-dev \
        libgl1-mesa-glx \
        libglew-dev \
        libosmesa6-dev \
        lsb-release \
        ack-grep \
        patchelf \
        wget \
        xpra \
        xserver-xorg-dev \
        ffmpeg
# !apt-get install python-opengl -y
# !apt install xvfb -y
# Out:
# Get:1 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:5 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Hit:7 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:8 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:10 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,165 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:12 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [3,279 kB]
# Get:13 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [2,428 kB]
# Get:14 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1,113 kB]
# Get:15 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [8,482 kB]
# Get:16 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,613 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [2,718 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,453 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [3,383 kB]
# Fetched 27.0 MB in 5s (5,222 kB/s)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# 58 packages can be upgraded. Run 'apt list --upgradable' to see them.
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# Note, selecting 'zlib1g-dev' instead of 'libz-dev'
# Note, selecting 'ack' instead of 'ack-grep'
# build-essential is already the newest version (12.9ubuntu3).
# libxi6 is already the newest version (2:1.8-1build1).
# libxi6 set to manually installed.
# libxrandr2 is already the newest version (2:1.5.2-1build1).
# libxrandr2 set to manually installed.
# lsb-release is already the newest version (11.1.0ubuntu4).
# lsb-release set to manually installed.
# make is already the newest version (4.3-4.1build1).
# make set to manually installed.
# cmake is already the newest version (3.22.1-1ubuntu1.22.04.2).
# git is already the newest version (1:2.34.1-1ubuntu1.11).
# unzip is already the newest version (6.0-26ubuntu3.2).
# wget is already the newest version (1.21.2-2ubuntu1.1).
# zlib1g-dev is already the newest version (1:1.2.11.dfsg-2ubuntu9.2).
# zlib1g-dev set to manually installed.
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# gnupg2 is already the newest version (2.2.27-3ubuntu2.1).
# The following additional packages will be installed:
#   gir1.2-atk-1.0 gir1.2-freedesktop gir1.2-gdkpixbuf-2.0 gir1.2-gtk-3.0 gir1.2-harfbuzz-0.0
#   gir1.2-pango-1.0 keyboard-configuration libcurl4 libcurl4-openssl-dev libdrm-dev libegl-dev
#   libfile-next-perl libfontenc-dev libfontenc1 libgl-dev libgles-dev libgles1 libglu1-mesa
#   libglu1-mesa-dev libglvnd-core-dev libglvnd-dev libglx-dev liblocale-gettext-perl libopengl-dev
#   libosmesa6 libpangoxft-1.0-0 libpciaccess-dev libpixman-1-dev libudev1 libxcvt-dev libxcvt0
#   libxfixes-dev libxfont-dev libxfont2 libxkbfile-dev libxkbfile1 libxtst6 mesa-common-dev
#   python3-cairo python3-rencode swig4.0 udev x11-xkb-utils x11-xserver-utils xserver-common
#   xserver-xorg-core xserver-xorg-video-dummy xvfb
# Suggested packages:
#   libcurl4-doc libidn11-dev libldap2-dev librtmp-dev libvulkan1 libglfw3-doc swig-doc swig-examples
#   swig4.0-examples swig4.0-doc nickle cairo-5c xorg-docs-core openssh-server python3-pyopencl
#   gstreamer1.0-plugins-base gstreamer1.0-plugins-good | gstreamer1.0-plugins-ugly
#   | gstreamer1.0-plugins-bad python3-gst-1.0 pulseaudio pulseaudio-utils python3-avahi
#   python3-netifaces cups-client cups-common cups-filters cups-pdf python3-cups python3-opencv
#   v4l2loopback-dkms python3-yaml python3-uinput xfonts-100dpi | xfonts-75dpi xfonts-scalable
# Recommended packages:
#   libegl1-mesa-dev libvulkan-dev libwayland-dev libxrandr-dev systemd-hwe-hwdb
#   gir1.2-appindicator3-0.1 python3-numpy python3-paramiko python3-dns ssh-askpass python3-lz4
#   python3-lzo python3-brotli python3-pil python3-opengl python3-setproctitle python3-zeroconf
#   python3-kerberos python3-gssapi python3-xdg python3-uritools python3-cpuinfo python3-pyinotify
#   xfonts-base xcvt
# The following NEW packages will be installed:
#   ack gir1.2-atk-1.0 gir1.2-freedesktop gir1.2-gdkpixbuf-2.0 gir1.2-gtk-3.0 gir1.2-harfbuzz-0.0
#   gir1.2-pango-1.0 keyboard-configuration libdrm-dev libegl-dev libfile-next-perl libfontenc-dev
#   libfontenc1 libgl-dev libgl1-mesa-dev libgl1-mesa-glx libgles-dev libgles1 libglew-dev libglfw3
#   libglfw3-dev libglu1-mesa libglu1-mesa-dev libglvnd-core-dev libglvnd-dev libglx-dev
#   liblocale-gettext-perl libopengl-dev libosmesa6 libosmesa6-dev libpangoxft-1.0-0 libpciaccess-dev
#   libpixman-1-dev libxcursor-dev libxcvt-dev libxcvt0 libxfixes-dev libxfont-dev libxfont2
#   libxinerama-dev libxkbfile-dev libxkbfile1 libxtst6 mesa-common-dev patchelf python3-cairo
#   python3-rencode swig swig4.0 udev x11-xkb-utils x11-xserver-utils xpra xserver-common
#   xserver-xorg-core xserver-xorg-dev xserver-xorg-video-dummy xvfb
# The following packages will be upgraded:
#   curl libcurl4 libcurl4-openssl-dev libudev1
# 4 upgraded, 58 newly installed, 0 to remove and 54 not upgraded.
# Need to get 18.3 MB of archives.
# After this operation, 70.7 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 liblocale-gettext-perl amd64 1.07-4build3 [17.1 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 keyboard-configuration all 1.205ubuntu3 [206 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libudev1 amd64 249.11-0ubuntu3.12 [78.2 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 udev amd64 249.11-0ubuntu3.12 [1,557 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libfile-next-perl all 1.18-1 [17.2 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/universe amd64 ack all 3.5.0-1 [70.4 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libcurl4-openssl-dev amd64 7.81.0-1ubuntu1.19 [386 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 curl amd64 7.81.0-1ubuntu1.19 [194 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libcurl4 amd64 7.81.0-1ubuntu1.19 [289 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy/main amd64 gir1.2-atk-1.0 amd64 2.36.0-3build1 [21.0 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy/main amd64 gir1.2-freedesktop amd64 1.72.0-1 [22.3 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 gir1.2-gdkpixbuf-2.0 amd64 2.42.8+dfsg-1ubuntu0.3 [9,486 B]
# Get:13 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 gir1.2-harfbuzz-0.0 amd64 2.7.4-1ubuntu3.1 [31.6 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libpangoxft-1.0-0 amd64 1.50.6+ds-2ubuntu1 [31.0 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 gir1.2-pango-1.0 amd64 1.50.6+ds-2ubuntu1 [44.0 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 gir1.2-gtk-3.0 amd64 3.24.33-1ubuntu2.2 [240 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy/main amd64 libpciaccess-dev amd64 0.16-3 [21.9 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libdrm-dev amd64 2.4.113-2~ubuntu0.22.04.1 [292 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglx-dev amd64 1.4.0-1 [14.1 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgl-dev amd64 1.4.0-1 [101 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy/main amd64 libegl-dev amd64 1.4.0-1 [18.0 kB]
# Get:22 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfontenc1 amd64 1:1.1.4-1build3 [14.7 kB]
# Get:23 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfontenc-dev amd64 1:1.1.4-1build3 [15.4 kB]
# Get:24 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libgl1-mesa-glx amd64 23.0.4-0ubuntu1~22.04.1 [5,584 B]
# Get:25 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgles1 amd64 1.4.0-1 [11.5 kB]
# Get:26 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgles-dev amd64 1.4.0-1 [49.4 kB]
# Get:27 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglvnd-core-dev amd64 1.4.0-1 [12.7 kB]
# Get:28 http://archive.ubuntu.com/ubuntu jammy/main amd64 libopengl-dev amd64 1.4.0-1 [3,400 B]
# Get:29 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglvnd-dev amd64 1.4.0-1 [3,162 B]
# Get:30 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgl1-mesa-dev amd64 23.2.1-1ubuntu3.1~22.04.2 [6,842 B]
# Get:31 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglu1-mesa amd64 9.0.2-1 [145 kB]
# Get:32 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglu1-mesa-dev amd64 9.0.2-1 [231 kB]
# Get:33 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libglew-dev amd64 2.2.0-4 [287 kB]
# Get:34 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libglfw3 amd64 3.3.6-1 [83.2 kB]
# Get:35 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libglfw3-dev amd64 3.3.6-1 [41.1 kB]
# Get:36 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libpixman-1-dev amd64 0.40.0-1ubuntu0.22.04.1 [280 kB]
# Get:37 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxfixes-dev amd64 1:6.0.0-1 [12.2 kB]
# Get:38 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcursor-dev amd64 1:1.2.0-2build4 [28.2 kB]
# Get:39 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcvt0 amd64 0.1.1-3 [5,494 B]
# Get:40 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcvt-dev amd64 0.1.1-3 [3,242 B]
# Get:41 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxfont2 amd64 1:2.0.5-1build1 [94.5 kB]
# Get:42 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxfont-dev amd64 1:2.0.5-1build1 [128 kB]
# Get:43 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxinerama-dev amd64 2:1.1.4-3 [8,104 B]
# Get:44 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxkbfile1 amd64 1:1.1.0-1build3 [71.8 kB]
# Get:45 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxkbfile-dev amd64 1:1.1.0-1build3 [85.0 kB]
# Get:46 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxtst6 amd64 2:1.2.3-1build4 [13.4 kB]
# Get:47 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 mesa-common-dev amd64 23.2.1-1ubuntu3.1~22.04.2 [2,208 kB]
# Get:48 http://archive.ubuntu.com/ubuntu jammy/universe amd64 patchelf amd64 0.14.3-1 [72.1 kB]
# Get:49 http://archive.ubuntu.com/ubuntu jammy/main amd64 python3-cairo amd64 1.20.1-3build1 [73.7 kB]
# Get:50 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-rencode amd64 1.0.6-2build1 [45.2 kB]
# Get:51 http://archive.ubuntu.com/ubuntu jammy/universe amd64 swig4.0 amd64 4.0.2-1ubuntu1 [1,110 kB]
# Get:52 http://archive.ubuntu.com/ubuntu jammy/universe amd64 swig all 4.0.2-1ubuntu1 [5,632 B]
# Get:53 http://archive.ubuntu.com/ubuntu jammy/main amd64 x11-xkb-utils amd64 7.7+5build4 [172 kB]
# Get:54 http://archive.ubuntu.com/ubuntu jammy/main amd64 x11-xserver-utils amd64 7.7+9build1 [170 kB]
# Get:55 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 xserver-common all 2:21.1.4-2ubuntu1.7~22.04.12 [28.7 kB]
# Get:56 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 xserver-xorg-core amd64 2:21.1.4-2ubuntu1.7~22.04.12 [1,477 kB]
# Get:57 http://archive.ubuntu.com/ubuntu jammy/main amd64 xserver-xorg-video-dummy amd64 1:0.3.8-2build1 [9,578 B]
# Get:58 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 xvfb amd64 2:21.1.4-2ubuntu1.7~22.04.12 [864 kB]
# Get:59 http://archive.ubuntu.com/ubuntu jammy/universe amd64 xpra amd64 3.1-1build5 [3,396 kB]
# Get:60 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 xserver-xorg-dev amd64 2:21.1.4-2ubuntu1.7~22.04.12 [204 kB]
# Get:61 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libosmesa6 amd64 23.2.1-1ubuntu3.1~22.04.2 [3,121 kB]
# Get:62 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libosmesa6-dev amd64 23.2.1-1ubuntu3.1~22.04.2 [8,984 B]
# Fetched 18.3 MB in 2s (8,369 kB/s)
# Extracting templates from packages: 100%
# Preconfiguring packages ...
# Selecting previously unselected package liblocale-gettext-perl.
# (Reading database ... 123629 files and directories currently installed.)
# Preparing to unpack .../liblocale-gettext-perl_1.07-4build3_amd64.deb ...
# Unpacking liblocale-gettext-perl (1.07-4build3) ...
# Selecting previously unselected package keyboard-configuration.
# Preparing to unpack .../keyboard-configuration_1.205ubuntu3_all.deb ...
# Unpacking keyboard-configuration (1.205ubuntu3) ...
# Preparing to unpack .../libudev1_249.11-0ubuntu3.12_amd64.deb ...
# Unpacking libudev1:amd64 (249.11-0ubuntu3.12) over (249.11-0ubuntu3.10) ...
# Setting up libudev1:amd64 (249.11-0ubuntu3.12) ...
# Selecting previously unselected package udev.
# (Reading database ... 123663 files and directories currently installed.)
# Preparing to unpack .../00-udev_249.11-0ubuntu3.12_amd64.deb ...
# Unpacking udev (249.11-0ubuntu3.12) ...
# Selecting previously unselected package libfile-next-perl.
# Preparing to unpack .../01-libfile-next-perl_1.18-1_all.deb ...
# Unpacking libfile-next-perl (1.18-1) ...
# Selecting previously unselected package ack.
# Preparing to unpack .../02-ack_3.5.0-1_all.deb ...
# Unpacking ack (3.5.0-1) ...
# Preparing to unpack .../03-libcurl4-openssl-dev_7.81.0-1ubuntu1.19_amd64.deb ...
# Unpacking libcurl4-openssl-dev:amd64 (7.81.0-1ubuntu1.19) over (7.81.0-1ubuntu1.18) ...
# Preparing to unpack .../04-curl_7.81.0-1ubuntu1.19_amd64.deb ...
# Unpacking curl (7.81.0-1ubuntu1.19) over (7.81.0-1ubuntu1.18) ...
# Preparing to unpack .../05-libcurl4_7.81.0-1ubuntu1.19_amd64.deb ...
# Unpacking libcurl4:amd64 (7.81.0-1ubuntu1.19) over (7.81.0-1ubuntu1.18) ...
# Selecting previously unselected package gir1.2-atk-1.0:amd64.
# Preparing to unpack .../06-gir1.2-atk-1.0_2.36.0-3build1_amd64.deb ...
# Unpacking gir1.2-atk-1.0:amd64 (2.36.0-3build1) ...
# Selecting previously unselected package gir1.2-freedesktop:amd64.
# Preparing to unpack .../07-gir1.2-freedesktop_1.72.0-1_amd64.deb ...
# Unpacking gir1.2-freedesktop:amd64 (1.72.0-1) ...
# Selecting previously unselected package gir1.2-gdkpixbuf-2.0:amd64.
# Preparing to unpack .../08-gir1.2-gdkpixbuf-2.0_2.42.8+dfsg-1ubuntu0.3_amd64.deb ...
# Unpacking gir1.2-gdkpixbuf-2.0:amd64 (2.42.8+dfsg-1ubuntu0.3) ...
# Selecting previously unselected package gir1.2-harfbuzz-0.0:amd64.
# Preparing to unpack .../09-gir1.2-harfbuzz-0.0_2.7.4-1ubuntu3.1_amd64.deb ...
# Unpacking gir1.2-harfbuzz-0.0:amd64 (2.7.4-1ubuntu3.1) ...
# Selecting previously unselected package libpangoxft-1.0-0:amd64.
# Preparing to unpack .../10-libpangoxft-1.0-0_1.50.6+ds-2ubuntu1_amd64.deb ...
# Unpacking libpangoxft-1.0-0:amd64 (1.50.6+ds-2ubuntu1) ...
# Selecting previously unselected package gir1.2-pango-1.0:amd64.
# Preparing to unpack .../11-gir1.2-pango-1.0_1.50.6+ds-2ubuntu1_amd64.deb ...
# Unpacking gir1.2-pango-1.0:amd64 (1.50.6+ds-2ubuntu1) ...
# Selecting previously unselected package gir1.2-gtk-3.0:amd64.
# Preparing to unpack .../12-gir1.2-gtk-3.0_3.24.33-1ubuntu2.2_amd64.deb ...
# Unpacking gir1.2-gtk-3.0:amd64 (3.24.33-1ubuntu2.2) ...
# Selecting previously unselected package libpciaccess-dev:amd64.
# Preparing to unpack .../13-libpciaccess-dev_0.16-3_amd64.deb ...
# Unpacking libpciaccess-dev:amd64 (0.16-3) ...
# Selecting previously unselected package libdrm-dev:amd64.
# Preparing to unpack .../14-libdrm-dev_2.4.113-2~ubuntu0.22.04.1_amd64.deb ...
# Unpacking libdrm-dev:amd64 (2.4.113-2~ubuntu0.22.04.1) ...
# Selecting previously unselected package libglx-dev:amd64.
# Preparing to unpack .../15-libglx-dev_1.4.0-1_amd64.deb ...
# Unpacking libglx-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libgl-dev:amd64.
# Preparing to unpack .../16-libgl-dev_1.4.0-1_amd64.deb ...
# Unpacking libgl-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libegl-dev:amd64.
# Preparing to unpack .../17-libegl-dev_1.4.0-1_amd64.deb ...
# Unpacking libegl-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libfontenc1:amd64.
# Preparing to unpack .../18-libfontenc1_1%3a1.1.4-1build3_amd64.deb ...
# Unpacking libfontenc1:amd64 (1:1.1.4-1build3) ...
# Selecting previously unselected package libfontenc-dev:amd64.
# Preparing to unpack .../19-libfontenc-dev_1%3a1.1.4-1build3_amd64.deb ...
# Unpacking libfontenc-dev:amd64 (1:1.1.4-1build3) ...
# Selecting previously unselected package libgl1-mesa-glx:amd64.
# Preparing to unpack .../20-libgl1-mesa-glx_23.0.4-0ubuntu1~22.04.1_amd64.deb ...
# Unpacking libgl1-mesa-glx:amd64 (23.0.4-0ubuntu1~22.04.1) ...
# Selecting previously unselected package libgles1:amd64.
# Preparing to unpack .../21-libgles1_1.4.0-1_amd64.deb ...
# Unpacking libgles1:amd64 (1.4.0-1) ...
# Selecting previously unselected package libgles-dev:amd64.
# Preparing to unpack .../22-libgles-dev_1.4.0-1_amd64.deb ...
# Unpacking libgles-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libglvnd-core-dev:amd64.
# Preparing to unpack .../23-libglvnd-core-dev_1.4.0-1_amd64.deb ...
# Unpacking libglvnd-core-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libopengl-dev:amd64.
# Preparing to unpack .../24-libopengl-dev_1.4.0-1_amd64.deb ...
# Unpacking libopengl-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libglvnd-dev:amd64.
# Preparing to unpack .../25-libglvnd-dev_1.4.0-1_amd64.deb ...
# Unpacking libglvnd-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libgl1-mesa-dev:amd64.
# Preparing to unpack .../26-libgl1-mesa-dev_23.2.1-1ubuntu3.1~22.04.2_amd64.deb ...
# Unpacking libgl1-mesa-dev:amd64 (23.2.1-1ubuntu3.1~22.04.2) ...
# Selecting previously unselected package libglu1-mesa:amd64.
# Preparing to unpack .../27-libglu1-mesa_9.0.2-1_amd64.deb ...
# Unpacking libglu1-mesa:amd64 (9.0.2-1) ...
# Selecting previously unselected package libglu1-mesa-dev:amd64.
# Preparing to unpack .../28-libglu1-mesa-dev_9.0.2-1_amd64.deb ...
# Unpacking libglu1-mesa-dev:amd64 (9.0.2-1) ...
# Selecting previously unselected package libglew-dev:amd64.
# Preparing to unpack .../29-libglew-dev_2.2.0-4_amd64.deb ...
# Unpacking libglew-dev:amd64 (2.2.0-4) ...
# Selecting previously unselected package libglfw3:amd64.
# Preparing to unpack .../30-libglfw3_3.3.6-1_amd64.deb ...
# Unpacking libglfw3:amd64 (3.3.6-1) ...
# Selecting previously unselected package libglfw3-dev:amd64.
# Preparing to unpack .../31-libglfw3-dev_3.3.6-1_amd64.deb ...
# Unpacking libglfw3-dev:amd64 (3.3.6-1) ...
# Selecting previously unselected package libpixman-1-dev:amd64.
# Preparing to unpack .../32-libpixman-1-dev_0.40.0-1ubuntu0.22.04.1_amd64.deb ...
# Unpacking libpixman-1-dev:amd64 (0.40.0-1ubuntu0.22.04.1) ...
# Selecting previously unselected package libxfixes-dev:amd64.
# Preparing to unpack .../33-libxfixes-dev_1%3a6.0.0-1_amd64.deb ...
# Unpacking libxfixes-dev:amd64 (1:6.0.0-1) ...
# Selecting previously unselected package libxcursor-dev:amd64.
# Preparing to unpack .../34-libxcursor-dev_1%3a1.2.0-2build4_amd64.deb ...
# Unpacking libxcursor-dev:amd64 (1:1.2.0-2build4) ...
# Selecting previously unselected package libxcvt0:amd64.
# Preparing to unpack .../35-libxcvt0_0.1.1-3_amd64.deb ...
# Unpacking libxcvt0:amd64 (0.1.1-3) ...
# Selecting previously unselected package libxcvt-dev:amd64.
# Preparing to unpack .../36-libxcvt-dev_0.1.1-3_amd64.deb ...
# Unpacking libxcvt-dev:amd64 (0.1.1-3) ...
# Selecting previously unselected package libxfont2:amd64.
# Preparing to unpack .../37-libxfont2_1%3a2.0.5-1build1_amd64.deb ...
# Unpacking libxfont2:amd64 (1:2.0.5-1build1) ...
# Selecting previously unselected package libxfont-dev.
# Preparing to unpack .../38-libxfont-dev_1%3a2.0.5-1build1_amd64.deb ...
# Unpacking libxfont-dev (1:2.0.5-1build1) ...
# Selecting previously unselected package libxinerama-dev:amd64.
# Preparing to unpack .../39-libxinerama-dev_2%3a1.1.4-3_amd64.deb ...
# Unpacking libxinerama-dev:amd64 (2:1.1.4-3) ...
# Selecting previously unselected package libxkbfile1:amd64.
# Preparing to unpack .../40-libxkbfile1_1%3a1.1.0-1build3_amd64.deb ...
# Unpacking libxkbfile1:amd64 (1:1.1.0-1build3) ...
# Selecting previously unselected package libxkbfile-dev:amd64.
# Preparing to unpack .../41-libxkbfile-dev_1%3a1.1.0-1build3_amd64.deb ...
# Unpacking libxkbfile-dev:amd64 (1:1.1.0-1build3) ...
# Selecting previously unselected package libxtst6:amd64.
# Preparing to unpack .../42-libxtst6_2%3a1.2.3-1build4_amd64.deb ...
# Unpacking libxtst6:amd64 (2:1.2.3-1build4) ...
# Selecting previously unselected package mesa-common-dev:amd64.
# Preparing to unpack .../43-mesa-common-dev_23.2.1-1ubuntu3.1~22.04.2_amd64.deb ...
# Unpacking mesa-common-dev:amd64 (23.2.1-1ubuntu3.1~22.04.2) ...
# Selecting previously unselected package patchelf.
# Preparing to unpack .../44-patchelf_0.14.3-1_amd64.deb ...
# Unpacking patchelf (0.14.3-1) ...
# Selecting previously unselected package python3-cairo:amd64.
# Preparing to unpack .../45-python3-cairo_1.20.1-3build1_amd64.deb ...
# Unpacking python3-cairo:amd64 (1.20.1-3build1) ...
# Selecting previously unselected package python3-rencode.
# Preparing to unpack .../46-python3-rencode_1.0.6-2build1_amd64.deb ...
# Unpacking python3-rencode (1.0.6-2build1) ...
# Selecting previously unselected package swig4.0.
# Preparing to unpack .../47-swig4.0_4.0.2-1ubuntu1_amd64.deb ...
# Unpacking swig4.0 (4.0.2-1ubuntu1) ...
# Selecting previously unselected package swig.
# Preparing to unpack .../48-swig_4.0.2-1ubuntu1_all.deb ...
# Unpacking swig (4.0.2-1ubuntu1) ...
# Selecting previously unselected package x11-xkb-utils.
# Preparing to unpack .../49-x11-xkb-utils_7.7+5build4_amd64.deb ...
# Unpacking x11-xkb-utils (7.7+5build4) ...
# Selecting previously unselected package x11-xserver-utils.
# Preparing to unpack .../50-x11-xserver-utils_7.7+9build1_amd64.deb ...
# Unpacking x11-xserver-utils (7.7+9build1) ...
# Selecting previously unselected package xserver-common.
# Preparing to unpack .../51-xserver-common_2%3a21.1.4-2ubuntu1.7~22.04.12_all.deb ...
# Unpacking xserver-common (2:21.1.4-2ubuntu1.7~22.04.12) ...
# Selecting previously unselected package xserver-xorg-core.
# Preparing to unpack .../52-xserver-xorg-core_2%3a21.1.4-2ubuntu1.7~22.04.12_amd64.deb ...
# Unpacking xserver-xorg-core (2:21.1.4-2ubuntu1.7~22.04.12) ...
# Selecting previously unselected package xserver-xorg-video-dummy.
# Preparing to unpack .../53-xserver-xorg-video-dummy_1%3a0.3.8-2build1_amd64.deb ...
# Unpacking xserver-xorg-video-dummy (1:0.3.8-2build1) ...
# Selecting previously unselected package xvfb.
# Preparing to unpack .../54-xvfb_2%3a21.1.4-2ubuntu1.7~22.04.12_amd64.deb ...
# Unpacking xvfb (2:21.1.4-2ubuntu1.7~22.04.12) ...
# Selecting previously unselected package xpra.
# Preparing to unpack .../55-xpra_3.1-1build5_amd64.deb ...
# Unpacking xpra (3.1-1build5) ...
# Selecting previously unselected package xserver-xorg-dev.
# Preparing to unpack .../56-xserver-xorg-dev_2%3a21.1.4-2ubuntu1.7~22.04.12_amd64.deb ...
# Unpacking xserver-xorg-dev (2:21.1.4-2ubuntu1.7~22.04.12) ...
# Selecting previously unselected package libosmesa6:amd64.
# Preparing to unpack .../57-libosmesa6_23.2.1-1ubuntu3.1~22.04.2_amd64.deb ...
# Unpacking libosmesa6:amd64 (23.2.1-1ubuntu3.1~22.04.2) ...
# Selecting previously unselected package libosmesa6-dev:amd64.
# Preparing to unpack .../58-libosmesa6-dev_23.2.1-1ubuntu3.1~22.04.2_amd64.deb ...
# Unpacking libosmesa6-dev:amd64 (23.2.1-1ubuntu3.1~22.04.2) ...
# Setting up libglfw3:amd64 (3.3.6-1) ...
# Setting up gir1.2-freedesktop:amd64 (1.72.0-1) ...
# Setting up libpixman-1-dev:amd64 (0.40.0-1ubuntu0.22.04.1) ...
# Setting up libpciaccess-dev:amd64 (0.16-3) ...
# Setting up python3-cairo:amd64 (1.20.1-3build1) ...
# Setting up python3-rencode (1.0.6-2build1) ...
# Setting up libpangoxft-1.0-0:amd64 (1.50.6+ds-2ubuntu1) ...
# Setting up libglvnd-core-dev:amd64 (1.4.0-1) ...
# Setting up gir1.2-gdkpixbuf-2.0:amd64 (2.42.8+dfsg-1ubuntu0.3) ...
# Setting up gir1.2-atk-1.0:amd64 (2.36.0-3build1) ...
# Setting up libxtst6:amd64 (2:1.2.3-1build4) ...
# Setting up x11-xserver-utils (7.7+9build1) ...
# Setting up gir1.2-harfbuzz-0.0:amd64 (2.7.4-1ubuntu3.1) ...
# Setting up libxfixes-dev:amd64 (1:6.0.0-1) ...
# Setting up libfontenc1:amd64 (1:1.1.4-1build3) ...
# Setting up gir1.2-pango-1.0:amd64 (1.50.6+ds-2ubuntu1) ...
# Setting up libgles1:amd64 (1.4.0-1) ...
# Setting up libfile-next-perl (1.18-1) ...
# Setting up udev (249.11-0ubuntu3.12) ...
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of start.
# Setting up libxinerama-dev:amd64 (2:1.1.4-3) ...
# Setting up libgl1-mesa-glx:amd64 (23.0.4-0ubuntu1~22.04.1) ...
# Setting up ack (3.5.0-1) ...
# Setting up libxcvt0:amd64 (0.1.1-3) ...
# Setting up libcurl4:amd64 (7.81.0-1ubuntu1.19) ...
# Setting up libglx-dev:amd64 (1.4.0-1) ...
# Setting up libglu1-mesa:amd64 (9.0.2-1) ...
# Setting up curl (7.81.0-1ubuntu1.19) ...
# Setting up libxkbfile1:amd64 (1:1.1.0-1build3) ...
# Setting up libopengl-dev:amd64 (1.4.0-1) ...
# Setting up patchelf (0.14.3-1) ...
# Setting up swig4.0 (4.0.2-1ubuntu1) ...
# Setting up libxfont2:amd64 (1:2.0.5-1build1) ...
# Setting up libgl-dev:amd64 (1.4.0-1) ...
# Setting up liblocale-gettext-perl (1.07-4build3) ...
# Setting up libxkbfile-dev:amd64 (1:1.1.0-1build3) ...
# Setting up libosmesa6:amd64 (23.2.1-1ubuntu3.1~22.04.2) ...
# Setting up libdrm-dev:amd64 (2.4.113-2~ubuntu0.22.04.1) ...
# Setting up swig (4.0.2-1ubuntu1) ...
# Setting up libxcvt-dev:amd64 (0.1.1-3) ...
# Setting up libglfw3-dev:amd64 (3.3.6-1) ...
# Setting up libegl-dev:amd64 (1.4.0-1) ...
# Setting up libxcursor-dev:amd64 (1:1.2.0-2build4) ...
# Setting up x11-xkb-utils (7.7+5build4) ...
# Setting up gir1.2-gtk-3.0:amd64 (3.24.33-1ubuntu2.2) ...
# Setting up libfontenc-dev:amd64 (1:1.1.4-1build3) ...
# Setting up libcurl4-openssl-dev:amd64 (7.81.0-1ubuntu1.19) ...
# Setting up libglu1-mesa-dev:amd64 (9.0.2-1) ...
# Setting up libosmesa6-dev:amd64 (23.2.1-1ubuntu3.1~22.04.2) ...
# Setting up mesa-common-dev:amd64 (23.2.1-1ubuntu3.1~22.04.2) ...
# Setting up xserver-common (2:21.1.4-2ubuntu1.7~22.04.12) ...
# Setting up keyboard-configuration (1.205ubuntu3) ...
# Your console font configuration will be updated the next time your system
# boots. If you want to update it now, run 'setupcon' from a virtual console.
# Setting up libgles-dev:amd64 (1.4.0-1) ...
# Setting up xvfb (2:21.1.4-2ubuntu1.7~22.04.12) ...
# Setting up libxfont-dev (1:2.0.5-1build1) ...
# Setting up xserver-xorg-core (2:21.1.4-2ubuntu1.7~22.04.12) ...
# Setting up libglvnd-dev:amd64 (1.4.0-1) ...
# Setting up xserver-xorg-video-dummy (1:0.3.8-2build1) ...
# Setting up libglew-dev:amd64 (2.2.0-4) ...
# Setting up libgl1-mesa-dev:amd64 (23.2.1-1ubuntu3.1~22.04.2) ...
# Setting up xserver-xorg-dev (2:21.1.4-2ubuntu1.7~22.04.12) ...
# Setting up xpra (3.1-1build5) ...
# .+..+.......+......+......+........+.+......+.....+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++*.....+.+...+..+...+............+.......+...+............+..+...+...+....+........+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++*........+...............+.............+......+.....+....+........+....+...+............+.........+.....+.+.....+....+...........+...+.+.........+.....+..........+......+..+.........+.+..............+.........+......................+..............+..........+...+...........+......+......+...+....+...+.....+..................+..........+...........+..........+.....+...+.....................+.+..............+......+...+............+................+..+.+.....+.....................+.+............+.................+.+...+..............+...+.............+......+...+......+...............+...........+.+...............+............+......+.........+..+..........+.........+.....+............+..........+..+......+.+......+........................+....................+......+.......+......+......+...............+...+......................................+.............+.....+......+....+.........+.....+.+..+........................+...+..................+...............+.........+......+...+.........+.......+...+......+.....+....+.................+.+...+..............+.......+...+.....+...+....+.......................+..........+..+...+.+......+...+...+..+.....................+.......+..+.......+.....+.+............+..................+............+...........+.+.........+..+...+.+...............+.....+...+......+....+..+...+...+..........+........+...................+........+...+.+......+..+.....................+.+..............+....+...+..............+.+..............+..........+...........+...+.................................................+...+.........+......+...+.........+..+..........+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# .....+....+.....+.+.....+...+...+............+...+.......+........+...+....+...+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++*..+..+....+...+..+......+....+......+..+.+..+...+.+...+......+.....+.+.....+..........+...+..+......+.........+.+...+.....+....+......+..+.........+....+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++*.+.............+.....+..................+.+...+..+..................+............+.........+....+......+..+............+.+.....+............+.........+...................+..........................+...+.......+........+.+..+...+...............+.......+...+..+...+.+...+...........+...............+....+.....+..........+...............+......+.........+...........+......+.+..+.......+...........+..........+..................+......+.........+..............+...+...+.+...+............+........+.+......+...........+...+....+...+.....+.........+.+..+.+......+...+......+......+........+...+.......+...+..+......+.+........+.+.....+.+...........+...+.......+.....+..............................+....+......+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# -----
# Processing triggers for dbus (1.12.20-2ubuntu4.1) ...
# Processing triggers for shared-mime-info (2.1-2) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.4) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# Processing triggers for man-db (2.10.2-1) ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# E: Unable to locate package python-opengl
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# xvfb is already the newest version (2:21.1.4-2ubuntu1.7~22.04.12).
# xvfb set to manually installed.
# 0 upgraded, 0 newly installed, 0 to remove and 54 not upgraded.

# %%
#@title clone homework repo

# %cd $SYM_PATH
# !git clone https://github.com/berkeleydeeprlcourse/homework_fall2023.git
# %cd hw1
# %pip install -r requirements_colab.txt
# %pip install -e .
# Out:
# /content/gdrive/My Drive/cs285_f2023
# fatal: destination path 'homework_fall2023' already exists and is not an empty directory.
# /content/gdrive/My Drive/cs285_f2023/hw1
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements_colab.txt'
# Obtaining file:///content/gdrive/My%20Drive/cs285_f2023/hw1
# ERROR: file:///content/gdrive/My%20Drive/cs285_f2023/hw1 does not appear to be a Python project: neither 'setup.py' nor 'pyproject.toml' found.

# %%
#@title set up virtual display

from pyvirtualdisplay import Display

display = Display(visible=0, size=(1400, 900))
display.start()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-a7c15be5f4c8> in <cell line: 3>()
#       1 #@title set up virtual display
#       2
# ----> 3 from pyvirtualdisplay import Display
#       4
#       5 display = Display(visible=0, size=(1400, 900))
#
# ModuleNotFoundError: No module named 'pyvirtualdisplay'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
#@title test virtual display

#@markdown If you see a video of a four-legged ant fumbling about, setup is complete!

import gym
from cs285.infrastructure.colab_utils import (
    wrap_env,
    show_video
)

env = wrap_env(gym.make("Ant-v4", render_mode='rgb_array'))

observation = env.reset()
for i in range(100):
    env.render()
    obs, rew, term, _ = env.step(env.action_space.sample() )
    if term:
      break;

env.close()
print('Loading video...')
show_video()

# %% [markdown]
# ## Editing Code
#
# To edit code, click the folder icon on the left menu. Navigate to the corresponding file (`cs285_f2020/...`). Double click a file to open an editor. You will need to edit code in the following files:
# ```markdown
# * cs285/policies/MLP_policy.py
# * cs285/infrastructure/utils.py
# * cs285/scripts/run_hw1.py
# ```

# %% [markdown]
# ## Run Behavior Cloning (Problem 1)
#
# Note that there is a timeout of about ~12 hours with Colab while it is active (and less if you close your browser window). We sync your edits to Google Drive so that you won't lose your work in the event of an instance timeout, but you will need to re-mount your Google Drive and re-install packages with every new instance.

# %%
#@title imports

import time

from cs285.scripts.run_hw1 import run_training_loop

# %load_ext autoreload
# %autoreload 2

# %%
#@title runtime arguments

class Args:

  def __getitem__(self, key):
    return getattr(self, key)

  def __setitem__(self, key, val):
    setattr(self, key, val)

  #@markdown expert data
  expert_policy_file = 'cs285/policies/experts/Ant.pkl' #@param
  expert_data = 'cs285/expert_data/expert_data_Ant-v4.pkl' #@param
  env_name = 'Ant-v4' #@param ['Ant-v4', 'Walker2d-v4', 'HalfCheetah-v4', 'Hopper-v4']
  exp_name = 'bc_ant' #@param
  do_dagger = True #@param {type: "boolean"}
  ep_len = 1000 #@param {type: "integer"}
  save_params = False #@param {type: "boolean"}

  num_agent_train_steps_per_iter = 1000 #@param {type: "integer"})
  n_iter = 5 #@param {type: "integer"})

  #@markdown batches & buffers
  batch_size_initial = 2000 #@param {type: "integer"})
  batch_size = 1000 #@param {type: "integer"})
  eval_batch_size = 1000 #@param {type: "integer"}
  train_batch_size = 100 #@param {type: "integer"}
  max_replay_buffer_size = 1000000 #@param {type: "integer"}

  #@markdown network
  n_layers = 2 #@param {type: "integer"}
  size = 64 #@param {type: "integer"}
  learning_rate = 5e-3 #@param {type: "number"}

  #@markdown logging
  video_log_freq = 5 #@param {type: "integer"}
  scalar_log_freq = 1 #@param {type: "integer"}

  #@markdown gpu & run-time settings
  no_gpu = False #@param {type: "boolean"}
  which_gpu = 0 #@param {type: "integer"}
  seed = 1 #@param {type: "integer"}

args = Args()

# %%
#@title create directory for logging

if args.do_dagger:
    logdir_prefix = 'q2_'  # The autograder uses the prefix `q2_`
    assert args.n_iter>1, ('DAgger needs more than 1 iteration (n_iter>1) of training, to iteratively query the expert and train (after 1st warmstarting from behavior cloning).')
else:
    logdir_prefix = 'q1_'  # The autograder uses the prefix `q1_`
    assert args.n_iter==1, ('Vanilla behavior cloning collects expert data just once (n_iter=1)')

data_path ='/content/cs285_f2023/hw1/data'
if not (os.path.exists(data_path)):
    os.makedirs(data_path)
logdir = logdir_prefix + args.exp_name + '_' + args.env_name + \
         '_' + time.strftime("%d-%m-%Y_%H-%M-%S")
logdir = os.path.join(data_path, logdir)
args['logdir'] = logdir
if not(os.path.exists(logdir)):
    os.makedirs(logdir)

# %%
## run training
print(args.logdir)
run_training_loop(args)

# %%
#@markdown You can visualize your runs with tensorboard from within the notebook

# %load_ext tensorboard
# %tensorboard --logdir /content/cs285_f2023/hw1/data

# %% [markdown]
# ## Running DAgger (Problem 2)
# Modify the settings above:
# 1. check the `do_dagger` box
# 2. set `n_iters` to `10`
# 3. set `exp_name` to `dagger_{env_name}`
# and then rerun the code.
